# %% [markdown]
# ## Importing Modules

# %%
# Import required libraries

# Import visualisation modules
import matplotlib as mpl 
# %matplotlib inline 
import matplotlib.pyplot as plt 

#Import modules
import osmnx as ox
import pandas as pd
import geopandas as gpd
import numpy as np
import contextily as ctx

#Import datareading modules
import fiona
import urllib
from urllib.request import urlopen
import csv
import os
import tempfile
import shutil
from pathlib import Path

import warnings 
warnings.simplefilter(action='ignore')
ox.__version__
# Out:
# '1.2.2'

# %% [markdown]
# ## Data and Pre-processing
# Our project topic is about Tourism Development.
# References:
#
# Research question:
#
# Scope of Work:
#
# Our data includes:
# 1. Airbnb listing Data Year of from [Inside Airbnb website]()
# 2. Airbnb Listing Data Year of from [Inside Airbnb website]()
# 2. Tourism Attraction Data which is scrapped from [OpenStreetMap]()
# 3. Greenspace Data from [Ordnance Survey]()
# 4. Population Data from [Office of National Statistics (ONS) UK Government]()

# %% [markdown]
# ### Tourism Attraction Data

# %% [markdown]
# #### Scrapping Tourism Attraction Data
# We followed the instruction from this [tutorial]() to scrap tourism attraction Point of Interest(POI)s from OpenStreetMap website.
#
# The notebook demonstrates the process of gathering local amenity data from OpenStreetMap. Local amenity data of this sort could be used to improve the accuracy of a whole range of ML models. In this notebook, the idea is that that presence of these amenities could help us predict what an AirBnb host might charge.
#
# The notebook covered "How to make basic requests from OpenStreetMap using OSMnx", -author.

# %%
# Set up query
query = {'tourism':'attraction'}

# Run query
# Jin: I change ox.pois.pois_from_place to ox.geometries.geometries_from_place, for the adjustment of osmnx version change.
# details: https://stackoverflow.com/questions/71559143/what-happened-to-the-pois-module-in-osmnx-and-what-to-use-now
tourist_attraction = ox.geometries.geometries_from_place(
            'Greater London, UK',
            tags = query,
            which_result=1)

tourist_attraction.head(5)
# Out:
#                         historic                      name     tourism  \
# element_type osmid
# node         25524252   building           Blewcoat School  attraction
#              26559743        NaN                       NaN  attraction
#              252602371       NaN  London Bridge Experience  attraction
#              269236138       NaN      Little Holland House  attraction
#              293221901       NaN    Hall Place and Gardens  attraction
#
#                         wikidata                        wikipedia  \
# element_type osmid
# node         25524252   Q4926413               en:Blewcoat School
#              26559743        NaN                              NaN
#              252602371  Q7748032  en:The London Bridge Experience
#              269236138       NaN                              NaN
#              293221901  Q5642615                              NaN
#
#                                          geometry access barrier bicycle  \
# element_type osmid
# node         25524252   POINT (-0.13606 51.49830)    NaN     NaN     NaN
#              26559743   POINT (-0.14525 51.39520)    NaN     NaN     NaN
#              252602371  POINT (-0.08826 51.50639)    NaN     NaN     NaN
#              269236138  POINT (-0.17065 51.35530)    NaN     NaN     NaN
#              293221901   POINT (0.16023 51.44819)    NaN     NaN     NaN
#
#                        place  ... int_name source:description name:ban  \
# element_type osmid            ...
# node         25524252    NaN  ...      NaN                NaN      NaN
#              26559743    NaN  ...      NaN                NaN      NaN
#              252602371   NaN  ...      NaN                NaN      NaN
#              269236138   NaN  ...      NaN                NaN      NaN
#              293221901   NaN  ...      NaN                NaN      NaN
#
#                        name:eo name:hak name:mai name:pms name:tl name:sw  \
# element_type osmid
# node         25524252      NaN      NaN      NaN      NaN     NaN     NaN
#              26559743      NaN      NaN      NaN      NaN     NaN     NaN
#              252602371     NaN      NaN      NaN      NaN     NaN     NaN
#              269236138     NaN      NaN      NaN      NaN     NaN     NaN
#              293221901     NaN      NaN      NaN      NaN     NaN     NaN
#
#                        name:xmf
# element_type osmid
# node         25524252       NaN
#              26559743       NaN
#              252602371      NaN
#              269236138      NaN
#              293221901      NaN
#
# [5 rows x 359 columns]

# %%
print(f"Data frame is {tourist_attraction.shape[0]:,} x {tourist_attraction.shape[1]}")
# Out:
# Data frame is 344 x 359

# %% [markdown]
# #### Tourism Attraction Data Wrangling

# %%
# Exploring the data structure and attributes
tourist_attraction.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 344 entries, ('node', 25524252) to ('relation', 12942436)
# Data columns (total 359 columns):
#  #    Column                                  Dtype
# ---   ------                                  -----
#  0    historic                                object
#  1    name                                    object
#  2    tourism                                 object
#  3    wikidata                                object
#  4    wikipedia                               object
#  5    geometry                                geometry
#  6    access                                  object
#  7    barrier                                 object
#  8    bicycle                                 object
#  9    place                                   object
#  10   foot                                    object
#  11   addr:street                             object
#  12   layer                                   object
#  13   level                                   object
#  14   opening_hours                           object
#  15   operator                                object
#  16   phone                                   object
#  17   ref                                     object
#  18   created_by                              object
#  19   description                             object
#  20   natural                                 object
#  21   addr:city                               object
#  22   addr:housename                          object
#  23   addr:housenumber                        object
#  24   addr:postcode                           object
#  25   addr:suburb                             object
#  26   alt_name                                object
#  27   amenity                                 object
#  28   source:addr                             object
#  29   wheelchair                              object
#  30   attraction                              object
#  31   name:ru                                 object
#  32   species                                 object
#  33   zoo                                     object
#  34   addr:country                            object
#  35   addr:county                             object
#  36   addr:place                              object
#  37   shop                                    object
#  38   website                                 object
#  39   name:de                                 object
#  40   name:en                                 object
#  41   name:fr                                 object
#  42   name:zh                                 object
#  43   source                                  object
#  44   seamark:type                            object
#  45   designation                             object
#  46   highway                                 object
#  47   note                                    object
#  48   display                                 object
#  49   support                                 object
#  50   aircraft:type                           object
#  51   faces                                   object
#  52   name:af                                 object
#  53   name:ar                                 object
#  54   name:arz                                object
#  55   name:az                                 object
#  56   name:bcl                                object
#  57   name:be                                 object
#  58   name:be-x-old                           object
#  59   name:bg                                 object
#  60   name:bn                                 object
#  61   name:bo                                 object
#  62   name:ca                                 object
#  63   name:ce                                 object
#  64   name:ceb                                object
#  65   name:ckb                                object
#  66   name:cs                                 object
#  67   name:cy                                 object
#  68   name:da                                 object
#  69   name:el                                 object
#  70   name:es                                 object
#  71   name:et                                 object
#  72   name:eu                                 object
#  73   name:fa                                 object
#  74   name:fi                                 object
#  75   name:ga                                 object
#  76   name:gl                                 object
#  77   name:he                                 object
#  78   name:hi                                 object
#  79   name:hr                                 object
#  80   name:hu                                 object
#  81   name:hy                                 object
#  82   name:hyw                                object
#  83   name:id                                 object
#  84   name:is                                 object
#  85   name:it                                 object
#  86   name:ja                                 object
#  87   name:jv                                 object
#  88   name:ka                                 object
#  89   name:kk                                 object
#  90   name:kn                                 object
#  91   name:ko                                 object
#  92   name:lfn                                object
#  93   name:lt                                 object
#  94   name:lv                                 object
#  95   name:min                                object
#  96   name:mk                                 object
#  97   name:ml                                 object
#  98   name:mn                                 object
#  99   name:mr                                 object
#  100  name:ms                                 object
#  101  name:my                                 object
#  102  name:nl                                 object
#  103  name:nn                                 object
#  104  name:no                                 object
#  105  name:pl                                 object
#  106  name:pnb                                object
#  107  name:pt                                 object
#  108  name:ro                                 object
#  109  name:sco                                object
#  110  name:sh                                 object
#  111  name:sk                                 object
#  112  name:so                                 object
#  113  name:sq                                 object
#  114  name:sr                                 object
#  115  name:sv                                 object
#  116  name:ta                                 object
#  117  name:te                                 object
#  118  name:th                                 object
#  119  name:tr                                 object
#  120  name:tt                                 object
#  121  name:uk                                 object
#  122  name:ur                                 object
#  123  name:uz                                 object
#  124  name:vec                                object
#  125  name:vi                                 object
#  126  name:war                                object
#  127  name:wuu                                object
#  128  name:yue                                object
#  129  visibility                              object
#  130  wheelchair:description                  object
#  131  man_made                                object
#  132  navigation                              object
#  133  rotating                                object
#  134  title                                   object
#  135  material                                object
#  136  name:gan                                object
#  137  name:zh-Hans                            object
#  138  name:zh-Hant                            object
#  139  seamark:bridge:category                 object
#  140  seamark:bridge:clearance_height_closed  object
#  141  seamark:bridge:clearance_height_open    object
#  142  seamark:name                            object
#  143  contact:phone                           object
#  144  contact:website                         object
#  145  tactile_paving                          object
#  146  toilets:wheelchair                      object
#  147  leisure                                 object
#  148  email                                   object
#  149  3dmr                                    object
#  150  direction                               object
#  151  telephone_kiosk                         object
#  152  wikimedia_commons                       object
#  153  inscription                             object
#  154  memorial                                object
#  155  openplaques:id                          object
#  156  subject:wikidata                        object
#  157  subject:wikipedia                       object
#  158  hgv                                     object
#  159  noname                                  object
#  160  check_date:opening_hours                object
#  161  covered                                 object
#  162  lit                                     object
#  163  sport                                   object
#  164  surface                                 object
#  165  contact:facebook                        object
#  166  contact:instagram                       object
#  167  contact:twitter                         object
#  168  contact:youtube                         object
#  169  fhrs:id                                 object
#  170  indoor                                  object
#  171  addr:parentstreet                       object
#  172  crossing                                object
#  173  crossing_ref                            object
#  174  listed_status                           object
#  175  official_name                           object
#  176  addr:unit                               object
#  177  fixme                                   object
#  178  booth                                   object
#  179  colour                                  object
#  180  disused:amenity                         object
#  181  nodes                                   object
#  182  name:scn                                object
#  183  water                                   object
#  184  area                                    object
#  185  landuse                                 object
#  186  air_conditioning                        object
#  187  alt_name:es                             object
#  188  building                                object
#  189  epims:property_id                       object
#  190  highlight                               object
#  191  name:als                                object
#  192  name:ast                                object
#  193  name:ba                                 object
#  194  name:br                                 object
#  195  name:ne                                 object
#  196  name:pa                                 object
#  197  name:sl                                 object
#  198  name:tg                                 object
#  199  building:colour                         object
#  200  building:levels                         object
#  201  building:material                       object
#  202  architect                               object
#  203  architect:wikidata                      object
#  204  height                                  object
#  205  tower:type                              object
#  206  building:shape                          object
#  207  loc_name                                object
#  208  roof:colour                             object
#  209  roof:height                             object
#  210  roof:material                           object
#  211  roof:shape                              object
#  212  start_date                              object
#  213  use                                     object
#  214  disused                                 object
#  215  ship:type                               object
#  216  old_name                                object
#  217  check_date                              object
#  218  toilets                                 object
#  219  toilets:access                          object
#  220  charge                                  object
#  221  fee                                     object
#  222  denomination                            object
#  223  religion                                object
#  224  seamark:harbour:category                object
#  225  bridge                                  object
#  226  heritage                                object
#  227  alt_name1:en                            object
#  228  alt_name:en                             object
#  229  payment:alipay                          object
#  230  payment:american_express                object
#  231  payment:cash                            object
#  232  payment:maestro                         object
#  233  payment:mastercard                      object
#  234  payment:unionpay                        object
#  235  payment:visa                            object
#  236  internet_access                         object
#  237  internet_access:ssid                    object
#  238  is_in                                   object
#  239  building:part                           object
#  240  office                                  object
#  241  exhibit                                 object
#  242  outdoor                                 object
#  243  ship                                    object
#  244  url                                     object
#  245  capacity                                object
#  246  roof:levels                             object
#  247  short_name                              object
#  248  theatre:genre                           object
#  249  fence_type                              object
#  250  postal_code                             object
#  251  HE_ref                                  object
#  252  heritage:operator                       object
#  253  opening_hours:url                       object
#  254  ref:he                                  object
#  255  seasonal                                object
#  256  building:name                           object
#  257  fax                                     object
#  258  operator:type                           object
#  259  brand                                   object
#  260  brand:wikidata                          object
#  261  payment:debit_cards                     object
#  262  screen                                  object
#  263  image                                   object
#  264  name:zh2                                object
#  265  note:building:part                      object
#  266  tower                                   object
#  267  government                              object
#  268  he:inscription_date                     object
#  269  heritage:website                        object
#  270  ref:GB:nhle                             object
#  271  construction_date                       object
#  272  temporary                               object
#  273  temporary:building                      object
#  274  bridge:movable                          object
#  275  bridge:structure                        object
#  276  building:cladding                       object
#  277  common_name                             object
#  278  min_height                              object
#  279  name:ang                                object
#  280  name:fy                                 object
#  281  name:gu                                 object
#  282  name:lb                                 object
#  283  name:mzn                                object
#  284  name:yi                                 object
#  285  roof:orientation                        object
#  286  busway                                  object
#  287  cycleway                                object
#  288  lanes                                   object
#  289  maxspeed                                object
#  290  not:name                                object
#  291  shoulder                                object
#  292  sidewalk                                object
#  293  source:maxspeed                         object
#  294  alt_name:fr                             object
#  295  name:nan                                object
#  296  name:zh-HK                              object
#  297  contact:email                           object
#  298  advertising                             object
#  299  animated                                object
#  300  display_type                            object
#  301  luminous                                object
#  302  orientation                             object
#  303  dog                                     object
#  304  garden:style                            object
#  305  maxspeed:type                           object
#  306  name:bs                                 object
#  307  name:new                                object
#  308  name:oc                                 object
#  309  name:se                                 object
#  310  ref:whc                                 object
#  311  whc:criteria                            object
#  312  building:architecture                   object
#  313  dedication:wikidata                     object
#  314  diocese                                 object
#  315  year_of_construction                    object
#  316  alt_name:tr                             object
#  317  castle_type                             object
#  318  historic:civilization                   object
#  319  alt_name:zh                             object
#  320  fhrs:confidence_management              object
#  321  fhrs:hygiene                            object
#  322  fhrs:local_authority_id                 object
#  323  fhrs:rating                             object
#  324  fhrs:structural                         object
#  325  theatre:type                            object
#  326  operator:wikidata                       object
#  327  artist_name                             object
#  328  source:postcode                         object
#  329  studio                                  object
#  330  access:conditional                      object
#  331  max_level                               object
#  332  min_level                               object
#  333  tomb                                    object
#  334  locomotive:type                         object
#  335  flickr                                  object
#  336  cycleway:right                          object
#  337  lanes:backward                          object
#  338  busway:right                            object
#  339  room                                    object
#  340  artwork_type                            object
#  341  installed                               object
#  342  ways                                    object
#  343  name:la                                 object
#  344  type                                    object
#  345  toilets:female                          object
#  346  toilets:male                            object
#  347  name:sd                                 object
#  348  name:si                                 object
#  349  int_name                                object
#  350  source:description                      object
#  351  name:ban                                object
#  352  name:eo                                 object
#  353  name:hak                                object
#  354  name:mai                                object
#  355  name:pms                                object
#  356  name:tl                                 object
#  357  name:sw                                 object
#  358  name:xmf                                object
# dtypes: geometry(1), object(358)
# memory usage: 976.9+ KB

# %%
# Selecting variables needed
tourism_attraction = tourist_attraction[["name", "tourism", "geometry"]]

#Checking the data
tourism_attraction.head(5)
# Out:
#                                             name     tourism  \
# element_type osmid
# node         25524252            Blewcoat School  attraction
#              26559743                        NaN  attraction
#              252602371  London Bridge Experience  attraction
#              269236138      Little Holland House  attraction
#              293221901    Hall Place and Gardens  attraction
#
#                                          geometry
# element_type osmid
# node         25524252   POINT (-0.13606 51.49830)
#              26559743   POINT (-0.14525 51.39520)
#              252602371  POINT (-0.08826 51.50639)
#              269236138  POINT (-0.17065 51.35530)
#              293221901   POINT (0.16023 51.44819)

# %%
# Identifying NA values in rows of 'name' attribute
tourism_attraction[tourism_attraction.name.isna()]
# Out:
#                          name     tourism  \
# element_type osmid
# node         26559743     NaN  attraction
#              320446994    NaN  attraction
#              4189248446   NaN  attraction
#              4382359536   NaN  attraction
#              4395971090   NaN  attraction
#              5263136422   NaN  attraction
#              6344035585   NaN  attraction
#              6359405651   NaN  attraction
#              6447075569   NaN  attraction
#              10046275960  NaN  attraction
# way          520139095    NaN  attraction
#              851874002    NaN  attraction
#              851874003    NaN  attraction
#
#                                                                    geometry
# element_type osmid
# node         26559743                             POINT (-0.14525 51.39520)
#              320446994                            POINT (-0.18974 51.56601)
#              4189248446                           POINT (-0.13182 51.51099)
#              4382359536                           POINT (-0.00712 51.53556)
#              4395971090                           POINT (-0.12517 51.50665)
#              5263136422                           POINT (-0.26097 51.62773)
#              6344035585                           POINT (-0.20505 51.51787)
#              6359405651                           POINT (-0.30643 51.44514)
#              6447075569                           POINT (-0.09701 51.51678)
#              10046275960                          POINT (-0.14002 51.51121)
# way          520139095    POLYGON ((-0.18728 51.56813, -0.18753 51.56847...
#              851874002    LINESTRING (-0.16136 51.47601, -0.16132 51.475...
#              851874003    LINESTRING (-0.16133 51.47567, -0.16124 51.475...

# %%
# Counting the NA values
tourism_attraction.isnull().sum(axis=0).sort_values(ascending=False)[:12]
# Out:
# name        13
# tourism      0
# geometry     0
# dtype: int64

# %% [markdown]
# We treat NA values as a real tourism attraction, so we keep the tourism attraction without a name.

# %%
# Converting the data type in the name column as a string
tourism_attraction['name'] = tourism_attraction['name'].astype("string")
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Checking the conversion
tourism_attraction.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 344 entries, ('node', 25524252) to ('relation', 12942436)
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      331 non-null    string
#  1   tourism   344 non-null    object
#  2   geometry  344 non-null    geometry
# dtypes: geometry(1), object(1), string(1)
# memory usage: 20.1+ KB

# %%
# Keeping the first duplicate row
tourism_df = tourism_attraction.drop_duplicates(['name'])
tourism_df
# Out:
#                                             name     tourism  \
# element_type osmid
# node         25524252            Blewcoat School  attraction
#              26559743                       <NA>  attraction
#              252602371  London Bridge Experience  attraction
#              269236138      Little Holland House  attraction
#              293221901    Hall Place and Gardens  attraction
# ...                                          ...         ...
# relation     7220431                    Kew Pond  attraction
#              8048634              Chiswick House  attraction
#              8244923          Little Dean's Yard  attraction
#              8250949           Piccadilly Circus  attraction
#              12942436            Wembley Stadium  attraction
#
#                                                                  geometry
# element_type osmid
# node         25524252                           POINT (-0.13606 51.49830)
#              26559743                           POINT (-0.14525 51.39520)
#              252602371                          POINT (-0.08826 51.50639)
#              269236138                          POINT (-0.17065 51.35530)
#              293221901                           POINT (0.16023 51.44819)
# ...                                                                   ...
# relation     7220431    POLYGON ((-0.28578 51.48458, -0.28557 51.48482...
#              8048634    POLYGON ((-0.25857 51.48363, -0.25861 51.48360...
#              8244923    POLYGON ((-0.12759 51.49840, -0.12763 51.49825...
#              8250949    POLYGON ((-0.13466 51.50974, -0.13472 51.50982...
#              12942436   POLYGON ((-0.28036 51.55725, -0.28025 51.55727...
#
# [317 rows x 3 columns]

# %% [markdown]
# We decided to drop the duplicate tourism attraction and keep the first row of all duplication by 'name attributes.

# %%
# Saving the scrapped and cleaned data into local path
path = os.path.join('data')
filenm = 'tourism_attraction.csv'

if not os.path.exists(path):
    print(f"Creating {path} under {os.getcwd('/Users/listianingrumr/Documents/CASA/FSDS/fsds_assess')}")
    os.makedirs(path)
    
tourism_attraction.to_csv(os.path.join(path,filenm), index=False)
print("Done.")
# Out:
# Done.

# %% [markdown]
# After storing the data into local path, we push the data to github remote repository [URL](https://github.com/JinJiang22/fsds_GroupWork.git)

# %%
# Accessing the data through URL
url =

# %%
# Checking the tourism attraction data CRS

# %% [markdown]
# ### Greenspace Data
# Greenspace data is downloaded from Ordnance Survey website with selection in 4 tiles that covers all London areas, which are:
# 1. SP
# 2. SU
# 3. TL
# 4. TQ
#
# Using QGIS we merged the tiles and the data is ready to be pre-processed on the github link [URL]()

# %% [markdown]
# #### Accessing greenspace data

# %%
fiona.supported_drivers
# Out:
# {'DXF': 'rw',
#  'CSV': 'raw',
#  'OpenFileGDB': 'r',
#  'ESRIJSON': 'r',
#  'ESRI Shapefile': 'raw',
#  'FlatGeobuf': 'rw',
#  'GeoJSON': 'raw',
#  'GeoJSONSeq': 'rw',
#  'GPKG': 'raw',
#  'GML': 'rw',
#  'OGR_GMT': 'rw',
#  'GPX': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'DGN': 'raw',
#  'PCIDSK': 'raw',
#  'OGR_PDS': 'r',
#  'S57': 'r',
#  'SQLite': 'raw',
#  'TopoJSON': 'r'}

# %%
# Read the file from github repo URL
#url = "https://github.com/JinJiang22/fsds_GroupWork/blob/main/data/greenspace_merged.geojson"
#urllib.request.urlretrieve(url ,"greenspace_merged.geojson")
#greenspace_gdf = gpd.read_file(url)

# Read the file in local
greenspace_gdf = gpd.read_file(
    "../fsds_GroupWork/data/greenspace_merged.geojson"
)

# %% [markdown]
# #### Greenspace Data Wrangling

# %%
greenspace_gdf.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 49739 entries, 0 to 49738
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fid        49739 non-null  int64
#  1   id         49739 non-null  object
#  2   function   49739 non-null  object
#  3   distName1  13087 non-null  object
#  4   distName2  46 non-null     object
#  5   distName3  1 non-null      object
#  6   distName4  0 non-null      object
#  7   layer      49739 non-null  object
#  8   path       49739 non-null  object
#  9   geometry   49739 non-null  geometry
# dtypes: geometry(1), int64(1), object(8)
# memory usage: 3.8+ MB

# %%
# Exploring at the data structure and attributes
greenspace_gdf.head()
# Out:
#                                      id  \
# 0  E56DE74A-4CE2-13A9-E053-AAEFA00A0D0E
# 1  E56DE74A-4BB9-13A9-E053-AAEFA00A0D0E
# 2  E56DE843-A69A-13A9-E053-AAEFA00A0D0E
# 3  E56DE6CA-44B8-13A9-E053-AAEFA00A0D0E
# 4  E56DE848-686E-13A9-E053-AAEFA00A0D0E
#
#                                  function distName1 distName2 distName3  \
# 0                           Playing Field      None      None      None
# 1  Allotments Or Community Growing Spaces      None      None      None
# 2                              Play Space      None      None      None
# 3                              Play Space      None      None      None
# 4                              Play Space      None      None      None
#
#   distName4              layer  \
# 0      None  SP_GreenspaceSite
# 1      None  SP_GreenspaceSite
# 2      None  SP_GreenspaceSite
# 3      None  SP_GreenspaceSite
# 4      None  SP_GreenspaceSite
#
#                                                 path  \
# 0  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 1  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 2  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 3  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 4  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                                             geometry
# 0  MULTIPOLYGON Z (((492957.940 289585.690 0.000,...
# 1  MULTIPOLYGON Z (((492218.690 289828.830 0.000,...
# 2  MULTIPOLYGON Z (((492475.190 289982.670 0.000,...
# 3  MULTIPOLYGON Z (((492391.360 289988.480 0.000,...
# 4  MULTIPOLYGON Z (((493020.640 290076.310 0.000,...

# %%
# Identifying Na values in rows of function
greenspace_gdf[greenspace_gdf.function.isna()]
# Out:
# Empty GeoDataFrame
# Columns: [id, function, distName1, distName2, distName3, distName4, layer, path, geometry]
# Index: []

# %%
# Take a look at the data
greenspace_gdf.head(5)
# Out:
#                                      id  \
# 0  E56DE74A-4CE2-13A9-E053-AAEFA00A0D0E
# 1  E56DE74A-4BB9-13A9-E053-AAEFA00A0D0E
# 2  E56DE843-A69A-13A9-E053-AAEFA00A0D0E
# 3  E56DE6CA-44B8-13A9-E053-AAEFA00A0D0E
# 4  E56DE848-686E-13A9-E053-AAEFA00A0D0E
#
#                                  function distName1 distName2 distName3  \
# 0                           Playing Field      None      None      None
# 1  Allotments Or Community Growing Spaces      None      None      None
# 2                              Play Space      None      None      None
# 3                              Play Space      None      None      None
# 4                              Play Space      None      None      None
#
#   distName4              layer  \
# 0      None  SP_GreenspaceSite
# 1      None  SP_GreenspaceSite
# 2      None  SP_GreenspaceSite
# 3      None  SP_GreenspaceSite
# 4      None  SP_GreenspaceSite
#
#                                                 path  \
# 0  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 1  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 2  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 3  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 4  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                                             geometry
# 0  MULTIPOLYGON Z (((492957.940 289585.690 0.000,...
# 1  MULTIPOLYGON Z (((492218.690 289828.830 0.000,...
# 2  MULTIPOLYGON Z (((492475.190 289982.670 0.000,...
# 3  MULTIPOLYGON Z (((492391.360 289988.480 0.000,...
# 4  MULTIPOLYGON Z (((493020.640 290076.310 0.000,...

# %%
# Plot greenspace geometry
ax = greenspace_gdf.plot(alpha=0.5, color='red');
# Add background map, expressing target CRS so the basemap can be
# reprojected (warped)
ctx.add_basemap(ax, crs=greenspace_gdf.crs)

# %% [markdown]
# ### London Ward Data

# %% [markdown]
# #### Accessing London Ward Data

# %%
# Add London Ward Boundary Data
londonward = gpd.read_file(
    "../fsds_GroupWork/data/londonward.gpkg"
)

# %%
# Take a look at the London Ward data
londonward.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        657 non-null    object
#  1   GSS_CODE    657 non-null    object
#  2   DISTRICT    657 non-null    object
#  3   LAGSSCODE   657 non-null    object
#  4   HECTARES    657 non-null    float64
#  5   NONLD_AREA  657 non-null    float64
#  6   geometry    657 non-null    geometry
# dtypes: float64(2), geometry(1), object(4)
# memory usage: 36.1+ KB

# %%
londonward.head(5)
# Out:
#                      NAME   GSS_CODE              DISTRICT  LAGSSCODE  \
# 0       Chessington South  E05000405  Kingston upon Thames  E09000021
# 1  Tolworth and Hook Rise  E05000414  Kingston upon Thames  E09000021
# 2              Berrylands  E05000401  Kingston upon Thames  E09000021
# 3               Alexandra  E05000400  Kingston upon Thames  E09000021
# 4                Beverley  E05000402  Kingston upon Thames  E09000021
#
#    HECTARES  NONLD_AREA                                           geometry
# 0   755.173         0.0  MULTIPOLYGON (((516401.596 160201.802, 516407....
# 1   259.464         0.0  MULTIPOLYGON (((519552.998 164295.600, 519508....
# 2   145.390         0.0  MULTIPOLYGON (((518107.499 167303.399, 518114....
# 3   268.506         0.0  MULTIPOLYGON (((520336.700 165105.498, 520332....
# 4   187.821         0.0  MULTIPOLYGON (((521201.203 169275.505, 521204....

# %%
# Plot the London Ward boundary to check
londonward.plot(cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Clip the Tourism Attraction Data

# %% [markdown]
# ### Calculate the Tourism Attraction Centroid

# %% [markdown]
# ### Clipping the Greenspace Data
#
# As mentioned before, the data included four tiles that covered London nearby areas. Now we need to clip our data with London Boundary because our study case location is London.

# %%
# check if they are in the same crs
print("greenspace", greenspace_gdf.crs)
print("londonward", londonward.crs)
# Out:
# greenspace epsg:27700
# londonward epsg:27700

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(12, 8))

greenspace_gdf.plot(alpha=.8,
                        color="green",
                         ax=ax,
                    )

londonward.plot(cmap='Blues',
                       ax=ax,
                       alpha=.5,
                    )

plt.axis('equal')
ax.set_axis_off()
plt.show()

# %%
# Clip the data using GeoPandas clip
greenspace_clip = gpd.clip(greenspace_gdf, londonward)

# View the first 6 rows and a few select columns
greenspace_clip.head()
# Out:
#          fid                                    id               function  \
# 43299  43300  E56DE6C5-31F0-13A9-E053-AAEFA00A0D0E  Other Sports Facility
# 43439  43440  E56DE74B-960A-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43443  43444  E56DE6D1-FF13-13A9-E053-AAEFA00A0D0E           Tennis Court
# 43446  43447  E56DE74B-9587-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43444  43445  E56DE74B-A73D-13A9-E053-AAEFA00A0D0E  Other Sports Facility
#
#                                       distName1 distName2 distName3 distName4  \
# 43299                                      None      None      None      None
# 43439                                      None      None      None      None
# 43443                                      None      None      None      None
# 43446  Roman Catholic Church of the Holy Family      None      None      None
# 43444                                      None      None      None      None
#
#                    layer                                               path  \
# 43299  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43439  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43443  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43446  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43444  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                                                 geometry
# 43299  POLYGON Z ((535015.300 159599.140 0.000, 53501...
# 43439  POLYGON Z ((534311.880 160595.980 0.000, 53429...
# 43443  POLYGON Z ((534415.150 160731.550 0.000, 53447...
# 43446  POLYGON Z ((534250.500 160869.900 0.000, 53427...
# 43444  POLYGON Z ((534961.620 160872.400 0.000, 53472...

# %%
# Plot the clipped data
fig, ax = plt.subplots(figsize=(12, 8))

greenspace_clip.plot(alpha=1,
                         color="white",
                         edgecolor="black",
                         ax=ax)

londonward.plot(cmap="Greys",
                       ax=ax,
                       alpha=.5)

ax.set_axis_off()
plt.axis('equal')

plt.show()

# %%
greenspace_area = greenspace_clip.sjoin(londonward, how="inner", predicate='intersects')

greenspace_area.head()
# Out:
#          fid                                    id               function  \
# 43299  43300  E56DE6C5-31F0-13A9-E053-AAEFA00A0D0E  Other Sports Facility
# 43439  43440  E56DE74B-960A-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43443  43444  E56DE6D1-FF13-13A9-E053-AAEFA00A0D0E           Tennis Court
# 43446  43447  E56DE74B-9587-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43444  43445  E56DE74B-A73D-13A9-E053-AAEFA00A0D0E  Other Sports Facility
#
#                                       distName1 distName2 distName3 distName4  \
# 43299                                      None      None      None      None
# 43439                                      None      None      None      None
# 43443                                      None      None      None      None
# 43446  Roman Catholic Church of the Holy Family      None      None      None
# 43444                                      None      None      None      None
#
#                    layer                                               path  \
# 43299  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43439  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43443  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43446  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43444  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                                                 geometry  index_right  \
# 43299  POLYGON Z ((535015.300 159599.140 0.000, 53501...           22
# 43439  POLYGON Z ((534311.880 160595.980 0.000, 53429...           22
# 43443  POLYGON Z ((534415.150 160731.550 0.000, 53447...           22
# 43446  POLYGON Z ((534250.500 160869.900 0.000, 53427...           22
# 43444  POLYGON Z ((534961.620 160872.400 0.000, 53472...           22
#
#               NAME   GSS_CODE DISTRICT  LAGSSCODE  HECTARES  NONLD_AREA
# 43299  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43439  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43443  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43446  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43444  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0

# %%
greenspace_area["total_area"] = greenspace_area['geometry'].area
greenspace_area.head(5)
# Out:
#          fid                                    id               function  \
# 43299  43300  E56DE6C5-31F0-13A9-E053-AAEFA00A0D0E  Other Sports Facility
# 43439  43440  E56DE74B-960A-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43443  43444  E56DE6D1-FF13-13A9-E053-AAEFA00A0D0E           Tennis Court
# 43446  43447  E56DE74B-9587-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43444  43445  E56DE74B-A73D-13A9-E053-AAEFA00A0D0E  Other Sports Facility
#
#                                       distName1 distName2 distName3 distName4  \
# 43299                                      None      None      None      None
# 43439                                      None      None      None      None
# 43443                                      None      None      None      None
# 43446  Roman Catholic Church of the Holy Family      None      None      None
# 43444                                      None      None      None      None
#
#                    layer                                               path  \
# 43299  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43439  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43443  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43446  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43444  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                                                 geometry  index_right  \
# 43299  POLYGON Z ((535015.300 159599.140 0.000, 53501...           22
# 43439  POLYGON Z ((534311.880 160595.980 0.000, 53429...           22
# 43443  POLYGON Z ((534415.150 160731.550 0.000, 53447...           22
# 43446  POLYGON Z ((534250.500 160869.900 0.000, 53427...           22
# 43444  POLYGON Z ((534961.620 160872.400 0.000, 53472...           22
#
#               NAME   GSS_CODE DISTRICT  LAGSSCODE  HECTARES  NONLD_AREA  \
# 43299  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43439  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43443  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43446  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
# 43444  Sanderstead  E05011478  Croydon  E09000008   753.708         0.0
#
#         total_area
# 43299   1112.25490
# 43439   2197.19465
# 43443   5158.09625
# 43446   3155.67165
# 43444  53191.16920

# %%
# Counting greenspace area by ward
greenspace_total_area = greenspace_area.groupby("GSS_CODE").sum("total_area")

greenspace_total_area.head()
# Out:
#               fid  index_right  HECTARES  NONLD_AREA    total_area
# GSS_CODE
# E05000026  379401         7428  1539.504       31.86  3.451667e+05
# E05000027  354469         5625  1227.978        0.00  6.548567e+05
# E05000028  251780         4992  1030.472        0.00  7.713161e+05
# E05000029  579323        10710  5753.174        0.00  8.520847e+05
# E05000030  403063         6290  3450.600        0.00  2.031153e+06

# %%
# Assign counts into a table of its own 
# and joins it to the areas table
ward = londonward.join(
    pd.DataFrame({"greenspace_ward": greenspace_total_area}),
    on="GSS_CODE"
)

ward.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [245], in <cell line: 3>()
#       1 # Assign counts into a table of its own
#       2 # and joins it to the areas table
#       3 ward = londonward.join(
# ----> 4     pd.DataFrame({"greenspace_ward": greenspace_total_area}),
#       5 )
#       7 ward.head(5)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/construction.py:664, in _extract_index(data)
#     661         raise ValueError("Per-column arrays must each be 1-dimensional")
#     663 if not indexes and not raw_lengths:
# --> 664     raise ValueError("If using all scalar values, you must pass an index")
#     666 elif have_series:
#     667     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %% [markdown]
# ### Calculating the Greenspace Centroid

# %%
# Calculating centroid of greenspace polygon and multipolygon

from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon

greenspace_centroid = greenspace_clip

greenspace_clip['geometry'] = greenspace_clip['geometry'].apply(
  lambda x: x.centroid if type(x) == Polygon else (
  x.centroid if type(x) == MultiPolygon else x)
)

greenspace_centroid.head(5)
# Out:
#                                          id               function  \
# 43299  E56DE6C5-31F0-13A9-E053-AAEFA00A0D0E  Other Sports Facility
# 43439  E56DE74B-960A-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43443  E56DE6D1-FF13-13A9-E053-AAEFA00A0D0E           Tennis Court
# 43446  E56DE74B-9587-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43444  E56DE74B-A73D-13A9-E053-AAEFA00A0D0E  Other Sports Facility
#
#                                       distName1 distName2 distName3 distName4  \
# 43299                                      None      None      None      None
# 43439                                      None      None      None      None
# 43443                                      None      None      None      None
# 43446  Roman Catholic Church of the Holy Family      None      None      None
# 43444                                      None      None      None      None
#
#                    layer                                               path  \
# 43299  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43439  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43443  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43446  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43444  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                             geometry
# 43299  POINT (534996.280 159576.615)
# 43439  POINT (534278.211 160594.285)
# 43443  POINT (534507.096 160783.952)
# 43446  POINT (534239.463 160835.475)
# 43444  POINT (534801.546 160893.843)

# %%
greenspace_centroid.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 10165 entries, 43299 to 27457
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         10165 non-null  object
#  1   function   10165 non-null  object
#  2   distName1  2752 non-null   object
#  3   distName2  10 non-null     object
#  4   distName3  1 non-null      object
#  5   distName4  0 non-null      object
#  6   layer      10165 non-null  object
#  7   path       10165 non-null  object
#  8   geometry   10165 non-null  geometry
# dtypes: geometry(1), object(8)
# memory usage: 794.1+ KB

# %%
# Plot the greenspace centroid
fig, ax = plt.subplots(figsize=(12, 8))

greenspace_centroid.plot(alpha=1,
                         color="white",
                         edgecolor="black",
                         ax=ax,
                        label = 'Greenspace \nLocations'
                    )

londonward.plot(cmap='Greys',
                       ax=ax,
                       alpha=.5)

ax.set_axis_off()
plt.axis('equal')

plt.show()

# %% [markdown]
# ### Defining greenspace centroid in each ward

# %% [markdown]
# First we calculate the points inside the ward area polygon. Since we dont have the same attributes to join, we use spatial join and define every centroids within each ward polygon
#
# Reference:
# https://geopandas.org/en/latest/docs/user_guide/mergingdata.html https://stackoverflow.com/questions/71579502/merging-pandas-file-with-osmnx

# %%
greenspace_in_ward = greenspace_centroid.sjoin(londonward, how="inner", predicate='intersects')

greenspace_in_ward.head()
# Out:
#                                          id               function  \
# 43299  E56DE6C5-31F0-13A9-E053-AAEFA00A0D0E  Other Sports Facility
# 43439  E56DE74B-960A-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43443  E56DE6D1-FF13-13A9-E053-AAEFA00A0D0E           Tennis Court
# 43446  E56DE74B-9587-13A9-E053-AAEFA00A0D0E      Religious Grounds
# 43444  E56DE74B-A73D-13A9-E053-AAEFA00A0D0E  Other Sports Facility
#
#                                       distName1 distName2 distName3 distName4  \
# 43299                                      None      None      None      None
# 43439                                      None      None      None      None
# 43443                                      None      None      None      None
# 43446  Roman Catholic Church of the Holy Family      None      None      None
# 43444                                      None      None      None      None
#
#                    layer                                               path  \
# 43299  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43439  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43443  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43446  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
# 43444  TQ_GreenspaceSite  /Users/listianingrumr/Documents/CASA/FSDS/fsds...
#
#                             geometry  index_right         NAME   GSS_CODE  \
# 43299  POINT (534996.280 159576.615)           22  Sanderstead  E05011478
# 43439  POINT (534278.211 160594.285)           22  Sanderstead  E05011478
# 43443  POINT (534507.096 160783.952)           22  Sanderstead  E05011478
# 43446  POINT (534239.463 160835.475)           22  Sanderstead  E05011478
# 43444  POINT (534801.546 160893.843)           22  Sanderstead  E05011478
#
#       DISTRICT  LAGSSCODE  HECTARES  NONLD_AREA
# 43299  Croydon  E09000008   753.708         0.0
# 43439  Croydon  E09000008   753.708         0.0
# 43443  Croydon  E09000008   753.708         0.0
# 43446  Croydon  E09000008   753.708         0.0
# 43444  Croydon  E09000008   753.708         0.0

# %%
greenspace_in_ward.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 10157 entries, 43299 to 30112
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10157 non-null  object
#  1   function     10157 non-null  object
#  2   distName1    2746 non-null   object
#  3   distName2    10 non-null     object
#  4   distName3    1 non-null      object
#  5   distName4    0 non-null      object
#  6   layer        10157 non-null  object
#  7   path         10157 non-null  object
#  8   geometry     10157 non-null  geometry
#  9   index_right  10157 non-null  int64
#  10  NAME         10157 non-null  object
#  11  GSS_CODE     10157 non-null  object
#  12  DISTRICT     10157 non-null  object
#  13  LAGSSCODE    10157 non-null  object
#  14  HECTARES     10157 non-null  float64
#  15  NONLD_AREA   10157 non-null  float64
# dtypes: float64(2), geometry(1), int64(1), object(12)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Calculating the density
#
# We calculate the density of each ward in London to use it as a variable in finding the relationship between tourism preference and greenspace.
#
# The formula for density is:

# %%
# Counting greenspace centroids by ward
greenspace_by_ward = greenspace_in_ward.groupby("GSS_CODE").size()

# %%
# Checking
greenspace_by_ward.head(5)
# Out:
# GSS_CODE
# E05000026    11
# E05000027     7
# E05000028     5
# E05000029    15
# E05000030     6
# dtype: int64

# %%
# Assign counts into a table of its own 
# and joins it to the areas table
ward = londonward.join(
    pd.DataFrame({"greenspace_count": greenspace_by_ward}),
    on="GSS_CODE"
)

ward.head(5)
# Out:
#                      NAME   GSS_CODE              DISTRICT  LAGSSCODE  \
# 0       Chessington South  E05000405  Kingston upon Thames  E09000021
# 1  Tolworth and Hook Rise  E05000414  Kingston upon Thames  E09000021
# 2              Berrylands  E05000401  Kingston upon Thames  E09000021
# 3               Alexandra  E05000400  Kingston upon Thames  E09000021
# 4                Beverley  E05000402  Kingston upon Thames  E09000021
#
#    HECTARES  NONLD_AREA                                           geometry  \
# 0   755.173         0.0  MULTIPOLYGON (((516401.596 160201.802, 516407....
# 1   259.464         0.0  MULTIPOLYGON (((519552.998 164295.600, 519508....
# 2   145.390         0.0  MULTIPOLYGON (((518107.499 167303.399, 518114....
# 3   268.506         0.0  MULTIPOLYGON (((520336.700 165105.498, 520332....
# 4   187.821         0.0  MULTIPOLYGON (((521201.203 169275.505, 521204....
#
#    greenspace_count
# 0              22.0
# 1               8.0
# 2              12.0
# 3              23.0
# 4              17.0

# %%
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(9, 9))
# Plot the equal interval choropleth and add a legend
ward.plot(
    column='greenspace_count', 
    scheme='quantiles', 
    ax=ax,
    legend=True,
    legend_kwds={"loc": 4}
)
# Remove the axes
ax.set_axis_off()
# Set the title
ax.set_title("Quantile map of greenspace counts by London Ward boundary")
# Add dark basemap
cx.add_basemap(
    ax, 
    crs="EPSG:27700",
    source=cx.providers.CartoDB.DarkMatterNoLabels
)
# Draw map
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [225], in <cell line: 16>()
#      14 ax.set_title("Quantile map of greenspace counts by London Ward boundary")
#      15 # Add dark basemap
# ---> 16 cx.add_basemap(
#      17     ax,
#      18     crs="EPSG:27700",
#      19     source=cx.providers.CartoDB.DarkMatterNoLabels
#      20 )
#      21 # Draw map
#      22 plt.show()
#
# NameError: name 'cx' is not defined

# %%
# Let’s first calculate the area in Sq. metres of each administrative delineation:
ward["area_sqm"] = ward.to_crs(epsg=27700).area * 1e-6

# %%
# Calculating greenspace density
ward["greenspace_density"] = ward["greenspace_count"] / ward["area_sqm"]

ward.head(5)
# Out:
#                      NAME   GSS_CODE              DISTRICT  LAGSSCODE  \
# 0       Chessington South  E05000405  Kingston upon Thames  E09000021
# 1  Tolworth and Hook Rise  E05000414  Kingston upon Thames  E09000021
# 2              Berrylands  E05000401  Kingston upon Thames  E09000021
# 3               Alexandra  E05000400  Kingston upon Thames  E09000021
# 4                Beverley  E05000402  Kingston upon Thames  E09000021
#
#    HECTARES  NONLD_AREA                                           geometry  \
# 0   755.173         0.0  MULTIPOLYGON (((516401.596 160201.802, 516407....
# 1   259.464         0.0  MULTIPOLYGON (((519552.998 164295.600, 519508....
# 2   145.390         0.0  MULTIPOLYGON (((518107.499 167303.399, 518114....
# 3   268.506         0.0  MULTIPOLYGON (((520336.700 165105.498, 520332....
# 4   187.821         0.0  MULTIPOLYGON (((521201.203 169275.505, 521204....
#
#    greenspace_count  area_sqm  greenspace_density
# 0              22.0  7.551784            2.913219
# 1               8.0  2.594673            3.083240
# 2              12.0  1.453889            8.253726
# 3              23.0  2.685017            8.566053
# 4              17.0  1.878205            9.051195

# %%
# Plot the density map
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(9, 9))
# Plot the equal interval choropleth and add a legend
ward.plot(
    column='greenspace_density', 
    scheme='quantiles', 
    ax=ax,
    legend=True,
    legend_kwds={"loc": 4}
)
# Remove the axes
ax.set_axis_off()
# Set the title
ax.set_title("Density map of greenspace in London Ward")
# Add dark basemap
cx.add_basemap(
    ax, 
    crs="EPSG:27700",
    source=cx.providers.CartoDB.DarkMatterNoLabels
)
# Draw map
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [229], in <cell line: 17>()
#      15 ax.set_title("Density map of greenspace in London Ward")
#      16 # Add dark basemap
# ---> 17 cx.add_basemap(
#      18     ax,
#      19     crs="EPSG:27700",
#      20     source=cx.providers.CartoDB.DarkMatterNoLabels
#      21 )
#      22 # Draw map
#      23 plt.show()
#
# NameError: name 'cx' is not defined
